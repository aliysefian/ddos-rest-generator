# %%
import requests
from random import randrange

# %%
data={
   "time_stamp":"2022-4-23 12:41:33.187",
   "department":1,
   "countries":[
     
      {
         "country":"GB",
         "CNT":2598.0,
         "BYTE":3440121.0
      },
      {
         "country":"TH",
         "CNT":0.0,
         "BYTE":116.0
      },
      {
         "country":"CY",
         "CNT":6.0,
         "BYTE":691.0
      },
      {
         "country":"UA",
         "CNT":7.0,
         "BYTE":1209.0
      },
      {
         "country":"US",
         "CNT":13969.0,
         "BYTE":15247792.0
      },
      {
         "country":"IN",
         "CNT":6.0,
         "BYTE":1085.0
      },
      {
         "country":"KR",
         "CNT":142.0,
         "BYTE":11505.0
      },
      {
         "country":"PH",
         "CNT":0.0,
         "BYTE":87.0
      },
      {
         "country":"BR",
         "CNT":2.0,
         "BYTE":1275.0
      },
      {
         "country":"BD",
         "CNT":0.0,
         "BYTE":165.0
      },
      {
         "country":"CN",
         "CNT":78.0,
         "BYTE":28389.0
      },
      {
         "country":"PL",
         "CNT":0.0,
         "BYTE":335.0
      },
      {
         "country":"RU",
         "CNT":116.0,
         "BYTE":144932.0
      },
      {
         "country":"SI",
         "CNT":0.0,
         "BYTE":41.0
      },
      {
         "country":"HK",
         "CNT":248.0,
         "BYTE":18122.0
      },
      {
         "country":"AU",
         "CNT":13.0,
         "BYTE":5946.0
      },
      {
         "country":"ME",
         "CNT":0.0,
         "BYTE":13.0
      },
      {
         "country":"TR",
         "CNT":253.0,
         "BYTE":166705.0
      },
      {
         "country":"IR",
         "CNT":12511.0,
         "BYTE":9693587.0
      },
      {
         "country":"ES",
         "CNT":1.0,
         "BYTE":214.0
      },
      {
         "country":"DE",
         "CNT":2488.0,
         "BYTE":3228790.0
      },
      {
         "country":"CH",
         "CNT":0.0,
         "BYTE":76.0
      },
      {
         "country":"MU",
         "CNT":0.0,
         "BYTE":8.0
      },
      {
         "country":"AL",
         "CNT":3.0,
         "BYTE":876.0
      },
      {
         "country":"AF",
         "CNT":0.0,
         "BYTE":9.0
      },
      {
         "country":"ID",
         "CNT":3.0,
         "BYTE":357.0
      },
      {
         "country":"ZA",
         "CNT":1.0,
         "BYTE":151.0
      },
      {
         "country":"IT",
         "CNT":2940.0,
         "BYTE":4202574.0
      },
      {
         "country":"BG",
         "CNT":0.0,
         "BYTE":57.0
      },
      {
         "country":"TW",
         "CNT":1.0,
         "BYTE":102.0
      },
      {
         "country":"KZ",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"DZ",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"CA",
         "CNT":28.0,
         "BYTE":16161.0
      },
      {
         "country":"BJ",
         "CNT":0.0,
         "BYTE":24.0
      },
      {
         "country":"HU",
         "CNT":16.0,
         "BYTE":24999.0
      },
      {
         "country":"SK",
         "CNT":3.0,
         "BYTE":1315.0
      },
      {
         "country":"JP",
         "CNT":1.0,
         "BYTE":1362.0
      },
      {
         "country":"VN",
         "CNT":0.0,
         "BYTE":242.0
      },
      {
         "country":"LK",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"AR",
         "CNT":0.0,
         "BYTE":132.0
      },
      {
         "country":"PE",
         "CNT":0.0,
         "BYTE":113.0
      },
      {
         "country":"MD",
         "CNT":310.0,
         "BYTE":401432.0
      },
      {
         "country":"RS",
         "CNT":0.0,
         "BYTE":25.0
      },
      {
         "country":"BO",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"SE",
         "CNT":9.0,
         "BYTE":3971.0
      },
      {
         "country":"VU",
         "CNT":49.0,
         "BYTE":56282.0
      },
      {
         "country":"AT",
         "CNT":28.0,
         "BYTE":37489.0
      },
      {
         "country":"NG",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"CZ",
         "CNT":1.0,
         "BYTE":154.0
      },
      {
         "country":"FR",
         "CNT":2782.0,
         "BYTE":3662096.0
      },
      {
         "country":"DO",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"AM",
         "CNT":0.0,
         "BYTE":614.0
      },
      {
         "country":"AZ",
         "CNT":10837.0,
         "BYTE":14307542.0
      },
      {
         "country":"IL",
         "CNT":0.0,
         "BYTE":24.0
      },
      {
         "country":"PK",
         "CNT":1.0,
         "BYTE":116.0
      },
      {
         "country":"MY",
         "CNT":0.0,
         "BYTE":61.0
      },
      {
         "country":"TZ",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"LV",
         "CNT":0.0,
         "BYTE":50.0
      },
      {
         "country":"EG",
         "CNT":1.0,
         "BYTE":163.0
      },
      {
         "country":"PT",
         "CNT":0.0,
         "BYTE":36.0
      },
      {
         "country":"BE",
         "CNT":0.0,
         "BYTE":14.0
      },
      {
         "country":"RO",
         "CNT":6.0,
         "BYTE":5077.0
      },
      {
         "country":"NO",
         "CNT":1.0,
         "BYTE":146.0
      },
      {
         "country":"LU",
         "CNT":26.0,
         "BYTE":4683.0
      },
      {
         "country":"IE",
         "CNT":11.0,
         "BYTE":9781.0
      },
      {
         "country":"DK",
         "CNT":2.0,
         "BYTE":347.0
      },
      {
         "country":"EE",
         "CNT":0.0,
         "BYTE":41.0
      },
      {
         "country":"TN",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"NZ",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"CL",
         "CNT":0.0,
         "BYTE":45.0
      },
      {
         "country":"SG",
         "CNT":7.0,
         "BYTE":931.0
      },
      {
         "country":"KH",
         "CNT":0.0,
         "BYTE":12.0
      },
      {
         "country":"BY",
         "CNT":0.0,
         "BYTE":53.0
      },
      {
         "country":"AE",
         "CNT":6.0,
         "BYTE":796.0
      },
      {
         "country":"IQ",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"SC",
         "CNT":6.0,
         "BYTE":450.0
      },
      {
         "country":"MK",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"VE",
         "CNT":0.0,
         "BYTE":19.0
      },
      {
         "country":"PA",
         "CNT":0.0,
         "BYTE":42.0
      },
      {
         "country":"FI",
         "CNT":5.0,
         "BYTE":2005.0
      },
      {
         "country":"NP",
         "CNT":0.0,
         "BYTE":27.0
      },
      {
         "country":"OM",
         "CNT":59.0,
         "BYTE":71359.0
      },
      {
         "country":"LB",
         "CNT":17.0,
         "BYTE":3567.0
      },
      {
         "country":"LT",
         "CNT":1.0,
         "BYTE":123.0
      },
      {
         "country":"GE",
         "CNT":0.0,
         "BYTE":29.0
      },
      {
         "country":"GR",
         "CNT":0.0,
         "BYTE":6.0
      },
      {
         "country":"BW",
         "CNT":0.0,
         "BYTE":6.0
      }
   ]
}

# %%
con=[]
for item  in data["countries"]:
    con.append(item["country"])

# %%
con
# Out:
# ['GB',
#  'TH',
#  'CY',
#  'UA',
#  'US',
#  'IN',
#  'KR',
#  'PH',
#  'BR',
#  'BD',
#  'CN',
#  'PL',
#  'RU',
#  'SI',
#  'HK',
#  'AU',
#  'ME',
#  'TR',
#  'IR',
#  'ES',
#  'DE',
#  'CH',
#  'MU',
#  'AL',
#  'AF',
#  'ID',
#  'ZA',
#  'IT',
#  'BG',
#  'TW',
#  'KZ',
#  'DZ',
#  'CA',
#  'BJ',
#  'HU',
#  'SK',
#  'JP',
#  'VN',
#  'LK',
#  'AR',
#  'PE',
#  'MD',
#  'RS',
#  'BO',
#  'SE',
#  'VU',
#  'AT',
#  'NG',
#  'CZ',
#  'FR',
#  'DO',
#  'AM',
#  'AZ',
#  'IL',
#  'PK',
#  'MY',
#  'TZ',
#  'LV',
#  'EG',
#  'PT',
#  'BE',
#  'RO',
#  'NO',
#  'LU',
#  'IE',
#  'DK',
#  'EE',
#  'TN',
#  'NZ',
#  'CL',
#  'SG',
#  'KH',
#  'BY',
#  'AE',
#  'IQ',
#  'SC',
#  'MK',
#  'VE',
#  'PA',
#  'FI',
#  'NP',
#  'OM',
#  'LB',
#  'LT',
#  'GE',
#  'GR',
#  'BW']

# %%
import datetime
datetime.datetime.now()
import json
import time

url = "http://127.0.0.1:8000/country-stats/insert-data/"

headers = {
  'Authorization': 'ali eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJsb29rdXBfaWQiOjM4OCwidXNlcl9pZCI6MSwidXNlcm5hbWUiOiIxIiwiZXhwIjoxMDI3NzE1MjY3NSwiZW1haWwiOiJhbGkxMzkxYWxpMTM5MUBnbWFpbC5jb20iLCJvcmlnX2lhdCI6MTYzNzIzOTA3NX0.8mnRF9oeC_Yu-5xd3FATg_5YlM9vofImfwUP50fcaLk',
  'Content-Type': 'application/json',
  'Cookie': 'token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJsb29rdXBfaWQiOjM3NCwidXNlcl9pZCI6MSwidXNlcm5hbWUiOiIxIiwiZXhwIjoxMDI1OTg2MTAzMCwiZW1haWwiOm51bGwsIm9yaWdfaWF0IjoxNjE5OTQ3NDMwfQ.wdjBzEb_EaTYDV5_hOmXUvF5oK_x6wARdli9WIbA19Q'
}


for _ in range(1000):
    data={"time_stamp":str(datetime.datetime.now()),
       "department":1,
    }
    countries=[]
    for item in con:
        countries.append({
            "country":item,
             "CNT":randrange(100),
             "BYTE":randrange(100)
        })
    data["countries"]=countries


    response = requests.request("POST", url, headers=headers, data=json.dumps(data))
    print(response.text)
    time.sleep(10) # Sleeping for ten second
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7504/1008809719.py in <module>
#      29     response = requests.request("POST", url, headers=headers, data=json.dumps(data))
#      30     print(response.text)
# ---> 31     time.sleep(10) # Sleeping for ten second
#
# KeyboardInterrupt:
